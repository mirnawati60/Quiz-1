# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('/content/AFATAR.jpg', 0)

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=700x392>

# %%
# cari dimensi dari gambar: width and height
width, height = image.size
print(f"Image dimensions: {width}x{height}")
# Out:
# Image dimensions: 700x392

# %%
# cari nilai maksimum dan nilai minimum pixel
import numpy as np
image_array = np.array(image)

max_pixel_value = np.max(image_array)
min_pixel_value = np.min(image_array)

print(f"Maximum pixel value: {max_pixel_value}")
print(f"Minimum pixel value: {min_pixel_value}")
# Out:
# Maximum pixel value: 255
# Minimum pixel value: 0

# %%
# lakukan proses normalisasi dari 0-255 ke 0-1
import numpy as np
normalized_image_array = image_array.astype(np.float32) / 255
normalized_image = Image.fromarray((normalized_image_array * 255).astype(np.uint8))
normalized_image.save('/content/AFATAR.jpg')

# %%
# silahkan lakukan transformasi geometri: flip horisontal dan flip vertikal.
image = cv2.imread('/content/AFATAR.jpg')
horizontal_flip = cv2.flip(image, 1)
vertical_flip = cv2.flip(image, 0)
cv2_imshow(image)
cv2_imshow(horizontal_flip)
cv2_imshow(vertical_flip)
# Out:
# <PIL.Image.Image image mode=RGB size=700x392>
# <PIL.Image.Image image mode=RGB size=700x392>
# <PIL.Image.Image image mode=RGB size=700x392>

# %%
#  tambahkan noise pada gambar: gaussian dan salt pepper
# Tambahkan noise Gaussian
mean = 0
std_dev = 50
gaussian_noise = np.random.normal(mean, std_dev, image.shape)
noisy_image = np.clip(image + gaussian_noise, 0, 255).astype(np.uint8)

# Tambahkan noise Salt and Pepper
salt_pepper_noise = np.zeros_like(image)
salt_pepper_prob = 0.05
salt_mask = np.random.rand(*image.shape[:2]) < salt_pepper_prob / 2
pepper_mask = np.random.rand(*image.shape[:2]) < salt_pepper_prob / 2
salt_pepper_noise[salt_mask] = 255
salt_pepper_noise[pepper_mask] = 0
noisy_image = cv2.add(noisy_image, salt_pepper_noise)

# %%
# lakukan crop dengan ukuran 250 x 250: random crop dan center crop
image = cv2.imread(image_path)
def random_crop(image, crop_size):
    height, width = image.shape[:2]
    x = random.randint(0, width - crop_size[1])
    y = random.randint(0, height - crop_size[0])
    cropped_image = image[y:y+crop_size[0], x:x+crop_size[1]]
    return cropped_image

# Fungsi untuk melakukan center crop
def center_crop(image, crop_size):
    height, width = image.shape[:2]
    start_y = height // 2 - crop_size[0] // 2
    start_x = width // 2 - crop_size[1] // 2
    cropped_image = image[start_y:start_y+crop_size[0], start_x:start_x+crop_size[1]]
    return cropped_image

# Random crop
random_cropped_image = random_crop(image, (250, 250))

# Center crop
center_cropped_image = center_crop(image, (250, 250))

# Tampilkan gambar hasil random crop
cv2.imshow('Random Cropped Image', random_cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# Tampilkan gambar hasil center crop
cv2.imshow('Center Cropped Image', center_cropped_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-32-ff3e16ea5cf8> in <cell line: 32>()
#      30
#      31 # Display random cropped image
# ---> 32 cv2.imshow('/content/AFATAR.jpg', random_cropped_image)
#      33 cv2.waitKey(0)
#      34 cv2.destroyAllWindows()
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      46   def wrapped(*args, **kwargs):
#      47     if not os.environ.get(env_var, False):
# ---> 48       raise DisabledFunctionError(message, name or func.__name__)
#      49     return func(*args, **kwargs)
#      50
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow
